# %%
import cv2
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# %%
image = Image.open('test00001.png')
data = np.array(np.asarray(image))

# %%
np.unique(data)
# Out:
# array([    0,     1,     2, 20000], dtype=int32)

# %%
data[data==20000] = 3
plt.imshow(data)
