# %%
import cv2
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# %%
image = Image.open('seg0001.png')
data = np.asarray(image)

# %%
np.unique(data)
# Out:
# array([0, 1, 2, 3], dtype=uint8)

# %%
plt.imshow(data)
